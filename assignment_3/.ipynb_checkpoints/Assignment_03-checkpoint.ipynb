# %% [markdown]
# # Assignment: 3 - Tamim Shaban

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from distfit import distfit

# %% [markdown]
# ## Q1

# %%
df = pd.read_excel("PopulationEstimates.xls", skiprows=2)
dfTX = df.loc[df['State'] == "TX"]
dfTX
# Out:
#        FIPS State        Area_Name  Rural-urban_Continuum Code_2003  \
# 2567  48000    TX            Texas                              NaN
# 2568  48001    TX  Anderson County                              5.0
# 2569  48003    TX   Andrews County                              6.0
# 2570  48005    TX  Angelina County                              5.0
# 2571  48007    TX   Aransas County                              2.0
# ...     ...   ...              ...                              ...
# 2817  48499    TX      Wood County                              6.0
# 2818  48501    TX    Yoakum County                              7.0
# 2819  48503    TX     Young County                              6.0
# 2820  48505    TX    Zapata County                              6.0
# 2821  48507    TX    Zavala County                              7.0
#
#       Rural-urban_Continuum Code_2013  Urban_Influence_Code_2003  \
# 2567                              NaN                        NaN
# ...

# %% [markdown]
# ## Q2

# %%
netImmagrationTX = dfTX['R_NET_MIG_2017']
bp = plt.boxplot(netImmagrationTX, labels=['1'])
plt.title('Boxplot of 2017 Net Immigration Rate of Texas Counties', fontdict={'size': 16})
plt.show()

# %% [markdown]
# ## Q3

# %%
dist = distfit()
data = netImmagrationTX.dropna()
data
# Out:
# 2567     6.606197
# 2568    12.266547
# 2569   -19.189525
# 2570    -3.578959
# 2571    12.836210
#           ...
# 2817    16.853869
# 2818   -22.424911
# 2819    -4.267938
# 2820   -21.782247
# 2821   -18.346339
# Name: R_NET_MIG_2017, Length: 255, dtype: float64

# %%
dist.fit_transform(data)
# Out:
# [distfit] >fit..
# [distfit] >transform..
# [distfit] >[norm      ] [RSS: 0.0002581] [loc=1.786 scale=20.744]
# [distfit] >[expon     ] [RSS: 0.0026484] [loc=-47.508 scale=49.294]
# [distfit] >[pareto    ] [RSS: 0.0029107] [loc=-772383.317 scale=772335.809]
# [distfit] >[dweibull  ] [RSS: 0.0002348] [loc=1.601 scale=15.866]
# [distfit] >[t         ] [RSS: 0.0001885] [loc=1.476 scale=15.732]
# [distfit] >[genextreme] [RSS: 0.0003993] [loc=-7.066 scale=19.041]
# [distfit] >[gamma     ] [RSS: 0.0121537] [loc=-47.508 scale=2.774]
# [distfit] >[lognorm   ] [RSS: 0.0010200] [loc=-48.826 scale=46.955]
# [distfit] >[beta      ] [RSS: 0.0002835] [loc=-101.528 scale=28940421.889]
# [distfit] >[uniform   ] [RSS: 0.0028982] [loc=-47.508 scale=197.706]
# [distfit] >Compute confidence interval [parametric]
# {'model': {'distr': <scipy.stats._continuous_distns.t_gen at 0x7f9789a28d60>,
#   'params': (5.3511119692912485, 1.4764325427238896, 15.732222665112928),
#   'name': 't',
# ...

# %%
dist.plot()
# Out:
# [distfit] >plot..
# (<Figure size 720x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'\nt\ndf=5.35, loc=1.48, scale=15.73'}, xlabel='Values', ylabel='Frequency'>)

# %%
dist.plot_summary()
# Out:
# [distfit] >plot summary..
# (<Figure size 1080x576 with 1 Axes>,
#  <AxesSubplot:title={'center':'Best fit: t'}, xlabel='Distribution name', ylabel='RSS (lower is better)'>)

# %% [markdown]
# The distribution type that minimizes the error value the most is the t-distribution.

# %% [markdown]
# ## Q4

# %%
#with sns.axes_style('white'):
with sns.plotting_context("notebook", font_scale=2):
    sns.jointplot("R_NATURAL_INC_2017", "R_birth_2017", dfTX, kind='reg', height=10)

# %% [markdown]
# ## Q5

# %%
tips = sns.load_dataset("tips")
with sns.axes_style(style='ticks'):
    with sns.plotting_context("notebook", font_scale=1.6):
        g = sns.factorplot("day", "total_bill", data=tips, kind="box", aspect=7/5)
